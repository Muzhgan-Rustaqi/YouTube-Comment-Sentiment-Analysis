# %% [markdown]
# # Question: what sentiment do users express in their     comments?

# %%
# to answer the question we first import all the libraries we need.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from wordcloud import WordCloud , STOPWORDS
import PIL
import os
from fontTools.ttLib import TTFont

# %%
# I load the data set

# %%
comments = pd.read_csv(r'C:\Users\Muzhg\Downloads\UScomments.csv',on_bad_lines='skip',  low_memory=False)

# %%
comments.head()
# Out:
#       video_id                                       comment_text likes  \
# 0  XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1  XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2  XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3  XpVt6Z1Gjjo                                MY FAN . attendance     3
# 4  XpVt6Z1Gjjo                                         trending 😉     3
#
#   replies
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# I clean my data set

# %%
comments.isnull().sum()
# Out:
# video_id         0
# comment_text    25
# likes            0
# replies          0
# dtype: int64

# %%
comments.dropna(inplace=True)

# %%
comments.isnull().sum()
# Out:
# video_id        0
# comment_text    0
# likes           0
# replies         0
# dtype: int64

# %% [markdown]
# #  Perform Sentiment Analysis

# %%
comments.head(1)
# Out:
#       video_id                       comment_text likes replies
# 0  XpVt6Z1Gjjo  Logan Paul it's yo big day ‼️‼️‼️     4       0

# %%
TextBlob("Logan Paul it's yo big day ‼️‼️‼️").sentiment.polarity
# Out:
# 0.0

# %%
comments.shape
# Out:
# (691375, 4)

# %%
polarity = []

for comment in comments['comment_text']:
    try:
        polarity.append(TextBlob(comment).sentiment.polarity)
    except:
        polarity.append(0)

# %%
len(polarity)
# Out:
# 691375

# %%
comments['polarity']  = polarity

# %%
comments.head(4)
# Out:
#       video_id                                       comment_text likes  \
# 0  XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1  XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2  XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3  XpVt6Z1Gjjo                                MY FAN . attendance     3
#
#   replies  polarity
# 0       0       0.0
# 1       0       0.0
# 2       0       0.0
# 3       0       0.0

# %%
filter1 = comments['polarity']==1

# %%
comments_positive = comments[filter1]

# %%
filter2 = comments['polarity']==-1

# %%
comments_negative = comments[filter2]

# %%
comments_positive.head(3)
# Out:
#         video_id                                       comment_text likes  \
# 64   XpVt6Z1Gjjo                                    yu are the best     1
# 156  cLdxuaxaQwc  Power is the disease.  Care is the cure.  Keep...     0
# 227  WYYvHb03Eog  YAS Can't wait to get it! I just need to sell ...     0
#
#     replies  polarity
# 64        0       1.0
# 156       0       1.0
# 227       0       1.0

# %%
set(STOPWORDS)
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
# ...

# %%
comments['comment_text']
# Out:
# 0                         Logan Paul it's yo big day ‼️‼️‼️
# 1         I've been following you from the start of your...
# 2                        Say hi to Kong and maverick for me
# 3                                       MY FAN . attendance
# 4                                                trending 😉
#                                 ...
# 691395                                               Лучшая
# 691396    qu'est ce que j'aimerais que tu viennes à Roan...
# 691397                            Ven a mexico! 😍 te amo LP
# 691398                                      Islığı yeter...
# 691399    Kocham tą piosenkę😍❤❤❤byłam zakochana po uszy ...
# Name: comment_text, Length: 691375, dtype: object

# %%
type(comments['comment_text'])
# Out:
# pandas.core.series.Series

# %%
total_comments_positive = ' '.join(comments_positive['comment_text'])

# %%
wordcloud = WordCloud(stopwords=set(STOPWORDS)).generate(total_comments_positive)

# %%
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
##### Conclusion-->> positive Users are emphasizing more on best , awesome , perfect , amazing , look , happy  etc..

# %%
total_comments_negative = ' '.join(comments_negative['comment_text'])

# %%
wordcloud2 = WordCloud(stopwords=set(STOPWORDS)).generate(total_comments_negative)

# %%
plt.imshow(wordcloud2)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
### Conclusion-->> Negative Users are emphasizing more on Terrible , worst ,horrible ,boring , disgusting etc
